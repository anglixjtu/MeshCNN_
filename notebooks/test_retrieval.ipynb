# %%
from options.opt import Opt
from data import CreateDataset
from torch_geometric.data import DataLoader
from models import CreateModel
from util.retriever import Retriever

# %%
opt = Opt() 
retriever = Retriever(opt)
dataset = CreateDataset(opt)
model = CreateModel(opt)
# Out:
# loaded mean / std from cache
# loading the model from ./checkpoints\MCBB_5c1000s\latest_net.pth

# %% [markdown]
# ## Extract features for the database

# %%
fea_db = retriever.extract_database_features(model, dataset)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Set query set

# %%
query_namelist =  ['test/gear/00070120.obj', 'test/gear/00000219.obj', 'test/motor/00053644.obj', 'test/motor/00064756.obj', 'test/pin/00052497.obj', 'test/pin/00052388.obj', 'test/rotor/00067691.obj', 'test/rotor/00067746.obj', 'test/washer/00040300.obj', 'test/washer/00041575.obj']
query_idx = []
for name in query_namelist:
    query_idx += [retriever.database_namelist.index(name)]
query_idx
# Out:
# [51, 42, 12, 7, 76, 63, 21, 38, 98, 93]

# %% [markdown]
# ## Test retrieval results of single examples

# %%
query_set = dataset[query_idx]
fea_q = fea_db[query_idx, :]

# %%
dist, ranked_list, dissm = retriever.retrieve(model, query_set, dataset, fea_db, fea_q)

# %%
retriever.show_results(query_idx, ranked_list, dissm)
# Out:
# D:\anaconda3\envs\torchgeo\lib\site-packages\pyvista\jupyter\notebook.py:56: UserWarning: Failed to use notebook backend:
#
# DLL load failed while importing vtkFiltersHyperTree: 内存资源不足，无法处理此命令。
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=500x1000 at 0x28E435461C0>

# %%
i=0
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/gear/00070120.obj
# D:\anaconda3\envs\torchgeo\lib\site-packages\pyvista\jupyter\notebook.py:56: UserWarning: Failed to use notebook backend:
#
# DLL load failed while importing vtkFiltersHyperTree: 内存资源不足，无法处理此命令。
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1C602317070>

# %%
i=1
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/gear/00000219.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1C60139BAF0>

# %%
i=3
print(retriever.query_namelist[i])
retriever.show_results([i], ranked_list, dissm)
# Out:
# test/motor/00064756.obj
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-548745fb3f4a> in <module>
#       1 i=3
#       2 print(retriever.query_namelist[i])
# ----> 3 retriever.show_results([i], ranked_list, dissm)
#
# e:\ARIH\3D_modeling\code\MeshCNN_\util\retriever.py in show_results(self, idx_query, idx_list, dissm)
#     114
#     115             for m, method in enumerate(self.methods):
# --> 116                 p.subplot(m + idx*num_methods, 0)
#     117                 # p.add_text("{}-query".format(method), font_size=font_size, color='black')
#     118                 filename = self.dataroot + self.database_namelist[idx].strip('\n')
#
# D:\anaconda3\envs\torchgeo\lib\site-packages\pyvista\plotting\plotting.py in subplot(self, index_row, index_column)
#     338
#     339         """
# --> 340         self.renderers.set_active_renderer(index_row, index_column)
#     341
#     342     @wraps(Renderer.add_floor)
#
# D:\anaconda3\envs\torchgeo\lib\site-packages\pyvista\plotting\renderers.py in set_active_renderer(self, index_row, index_column)
#     248
#     249         if index_row < 0 or index_row >= self.shape[0]:
# --> 250             raise IndexError(f'Row index is out of range ({self.shape[0]})')
#     251         if index_column < 0 or index_column >= self.shape[1]:
#     252             raise IndexError(f'Column index is out of range ({self.shape[1]})')
#
# IndexError: Row index is out of range (1)

# %%
i=30
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/handles/00048819.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1BF8408AF40>

# %%
i=40
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/bearing/00081165.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x2CB86CEB070>

# %%
i=50
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/bearing/00062800.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x2CB810EEB20>

# %%
i=60
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/rotor/00067617.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x2CBFBB3C340>

# %%
i=70
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/rotor/00075116.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1BFF9A610D0>

# %%
i=80
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/nut/00060365.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1BF89D4DFA0>

# %%
i=90
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/nut/00042796.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A3008E0490>

# %%
i=100
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/pin/00050640.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A361E66F10>

# %%
i=110
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/pin/00051760.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1BFF9A6CD60>

# %%
i=120
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/switch/00067292.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A3008E0A60>

# %%
i=130
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/switch/00054200.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A3008E0D90>

# %%
i=140
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/screws_and_bolts/00066779.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A3008C1790>

# %%
i=150
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/screws_and_bolts/00056631.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A3008E0610>

# %%
i=160
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/bushing/00041135.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A30042AE50>

# %%
i=170
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/bushing/00039626.obj
# <PIL.Image.Image image mode=RGB size=1024x400 at 0x2A300921190>

# %%
i=180
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/disc/00062415.obj
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1BF89D6A640>

# %%
i=190
print(retriever.query_namelist[i])
retriever.show_results(i, ranked_list, dissm)
# Out:
# test/disc/00077290.obj
# D:\anaconda3\envs\torchgeo\lib\site-packages\pyvista\jupyter\notebook.py:56: UserWarning: Failed to use notebook backend:
#
# DLL load failed while importing vtkFiltersGeneric: 内存资源不足，无法处理此命令。
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x300 at 0x1BF8A1D4070>
